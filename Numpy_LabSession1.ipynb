# %% [markdown]
# <a href="https://colab.research.google.com/github/prashantmishra1404/Numpy_Project/blob/main/Numpy_LabSession1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !gdown 1c0ClC8SrPwJq5rrkyMKyPn80nyHcFikK
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1c0ClC8SrPwJq5rrkyMKyPn80nyHcFikK
# To: /content/survey.txt
# 100% 2.55k/2.55k [00:00<00:00, 11.1MB/s]

# %%
scores = np.loadtxt("survey.txt", dtype = 'int')
scores
# Out:
# array([ 7, 10,  5, ...,  5,  9, 10])

# %%
scores.ndim
# Out:
# 1

# %%
len(scores)
# Out:
# 1167

# %%
scores.shape
# Out:
# (1167,)

# %%
#print first 10 user ratings
scores[:10]
# Out:
# array([ 7, 10,  5,  9,  9,  4,  7,  9,  9,  9])

# %%
# Question 1: What NumPy technique is used to filter scores where respondents are detractors scores (No of detractor you want to know)
scores <=6
# Out:
# array([False, False,  True, ...,  True, False, False])

# %%
scores[scores <=6]
# Out:
# array([5, 4, 4, 5, 1, 5, 5, 1, 4, 5, 4, 4, 4, 5, 1, 4, 1, 4, 1, 5, 5, 1,
#        1, 4, 1, 5, 4, 1, 1, 4, 1, 5, 1, 4, 4, 1, 1, 1, 1, 1, 1, 1, 4, 1,
#        1, 5, 5, 5, 4, 4, 1, 4, 1, 4, 1, 5, 1, 1, 5, 4, 4, 4, 4, 1, 4, 5,
#        4, 4, 1, 1, 5, 5, 1, 5, 1, 5, 5, 4, 5, 4, 1, 1, 1, 1, 4, 1, 4, 4,
#        5, 4, 1, 1, 1, 1, 5, 4, 5, 5, 4, 1, 5, 1, 4, 4, 1, 1, 1, 4, 4, 5,
#        5, 4, 5, 5, 5, 1, 4, 1, 5, 5, 1, 5, 1, 1, 5, 5, 4, 4, 1, 4, 4, 4,
#        1, 1, 4, 4, 4, 5, 5, 1, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 5, 4, 4,
#        5, 1, 4, 5, 5, 5, 1, 5, 4, 1, 1, 5, 5, 5, 4, 5, 4, 4, 1, 4, 4, 4,
#        4, 5, 1, 5, 5, 1, 4, 4, 5, 1, 1, 4, 5, 5, 5, 1, 4, 5, 5, 4, 1, 5,
#        5, 5, 1, 1, 5, 5, 1, 1, 1, 4, 5, 5, 4, 4, 4, 5, 1, 4, 1, 4, 5, 4,
#        5, 5, 1, 5, 1, 5, 5, 1, 4, 5, 5, 4, 1, 5, 1, 4, 1, 4, 1, 1, 1, 1,
#        1, 1, 4, 1, 5, 4, 5, 1, 5, 1, 5, 4, 4, 4, 4, 5, 5, 1, 4, 1, 5, 5,
#        1, 4, 1, 1, 4, 4, 4, 4, 1, 4, 1, 1, 4, 1, 5, 4, 1, 1, 5, 4, 5, 4,
# ...

# %%
detractors = len(scores[scores <=6])
detractors
# Out:
# 332

# %%
#Question 2: What NumPy technique is used to filter scores where respondents are promoters scores >= 9

# %%
scores[scores >=9]
# Out:
# array([10,  9,  9,  9,  9,  9, 10,  9,  9, 10,  9,  9,  9,  9,  9,  9,  9,
#        10, 10,  9, 10,  9, 10,  9,  9, 10, 10,  9, 10,  9, 10, 10, 10,  9,
#         9, 10, 10, 10,  9, 10,  9, 10,  9,  9,  9, 10,  9,  9,  9,  9,  9,
#         9, 10,  9,  9,  9, 10,  9, 10,  9,  9,  9,  9,  9, 10, 10,  9, 10,
#         9,  9, 10,  9,  9, 10,  9,  9,  9,  9,  9,  9,  9,  9,  9,  9,  9,
#        10,  9,  9,  9,  9,  9,  9,  9,  9, 10,  9,  9,  9,  9,  9, 10, 10,
#         9, 10, 10, 10, 10,  9, 10,  9,  9,  9,  9,  9,  9,  9, 10,  9, 10,
#         9, 10,  9, 10, 10, 10,  9,  9, 10, 10,  9,  9,  9,  9, 10,  9,  9,
#         9,  9, 10, 10,  9,  9,  9, 10,  9,  9,  9,  9,  9, 10,  9,  9,  9,
#        10,  9, 10, 10,  9,  9,  9,  9, 10,  9, 10,  9,  9,  9,  9, 10,  9,
#        10,  9,  9,  9,  9,  9,  9,  9,  9,  9,  9,  9, 10, 10,  9,  9,  9,
#        10,  9, 10, 10, 10, 10, 10,  9,  9,  9,  9, 10, 10, 10,  9,  9, 10,
# ...

# %%
scores >=9
# Out:
# array([False,  True, False, ..., False,  True,  True])

# %%
promoters = len(scores[scores >=9])
promoters
# Out:
# 609

# %%
#NPS SCORES= %promoters - %detractors

# %%
NPS = 100*(promoters - detractors)/ len(scores)
NPS
# Out:
# 23.736075407026565

# %%
round(NPS,2)
# Out:
# 23.74

# %% [markdown]
# # Use Case: Fitness data analysis
#
# <img src='https://drive.google.com/uc?id=1Uxwd4H-tfM64giRS1VExMpQXKtBBtuP0'>

# %%
# !gdown https://drive.google.com/uc?id=1vk1Pu0djiYcrdc85yUXZ_Rqq2oZNcohd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vk1Pu0djiYcrdc85yUXZ_Rqq2oZNcohd
# To: /content/fit.txt
# 100% 3.43k/3.43k [00:00<00:00, 13.3MB/s]

# %%
data = np.loadtxt('fit.txt', dtype= 'str')
# Out:
# /tmp/ipykernel_1613/2144111449.py:1: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   data = np.loadtxt('fit.txt', dtype= 'str')

# %%
data.shape
# Out:
# (96, 6)

# %%
#Column are
#Date, stepcount,mood,caloriesburned,hoursofsleep, activity status

# %%
data[:5]
# Out:
# array([['06-10-2017', '5464', 'Neutral', '181', '5', 'Inactive'],
#        ['07-10-2017', '6041', 'Sad', '197', '8', 'Inactive'],
#        ['08-10-2017', '25', 'Sad', '0', '5', 'Inactive'],
#        ['09-10-2017', '5461', 'Sad', '174', '4', 'Inactive'],
#        ['10-10-2017', '6915', 'Neutral', '223', '5', 'Active']],
#       dtype='<U10')

# %%
#first lets separate each and every column info
step_count = data[:,1].astype('int')
step_count
# Out:
# array([5464, 6041,   25, 5461, 6915, 4545, 4340, 1230,   61, 1258, 3148,
#        4687, 4732, 3519, 1580, 2822,  181, 3158, 4383, 3881, 4037,  202,
#         292,  330, 2209, 4550, 4435, 4779, 1831, 2255,  539, 5464, 6041,
#        4068, 4683, 4033, 6314,  614, 3149, 4005, 4880, 4136,  705,  570,
#         269, 4275, 5999, 4421, 6930, 5195,  546,  493,  995, 1163, 6676,
#        3608,  774, 1421, 4064, 2725, 5934, 1867, 3721, 2374, 2909, 1648,
#         799, 7102, 3941, 7422,  437, 1231, 1696, 4921,  221, 6500, 3575,
#        4061,  651,  753,  518, 5537, 4108, 5376, 3066,  177,   36,  299,
#        1447, 2599,  702,  133,  153,  500, 2127, 2203])

# %%
mood = data[:,2]
calories = data[:,3].astype('int')
sleep = data[:,4].astype('int')
activity = data[:,5]

# %%
#Question: What is the average step count on "Active" days?

# %%
activity[activity == 'Active' ]
# Out:
# array(['Active', 'Active', 'Active', 'Active', 'Active', 'Active',
#        'Active', 'Active', 'Active', 'Active', 'Active', 'Active',
#        'Active', 'Active', 'Active', 'Active', 'Active', 'Active',
#        'Active', 'Active', 'Active', 'Active', 'Active', 'Active',
#        'Active', 'Active', 'Active', 'Active', 'Active', 'Active',
#        'Active', 'Active', 'Active', 'Active', 'Active', 'Active',
#        'Active', 'Active', 'Active', 'Active', 'Active', 'Active'],
#       dtype='<U10')

# %%
step_count[activity == 'Active']
# Out:
# array([6915, 4732, 4550,  539, 6314,  614, 3149, 4005, 4880, 4136,  705,
#         570,  269,  493,  995, 1163, 6676, 3608,  774, 1421, 4064, 2725,
#        5934, 1867, 3721, 2909, 1648, 7102, 3941, 7422,  437, 1231, 4921,
#         221, 6500, 3575, 5537, 4108, 5376, 3066,  500, 2203])

# %%
print(np.mean(step_count[activity == 'Active']))
# Out:
# 3226.5714285714284

# %%
step_count > 5000
# Out:
# array([ True,  True, False,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True,  True, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False,  True, False,  True,  True, False, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False, False, False,  True, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
calories > 150
# Out:
# array([ True,  True, False,  True,  True, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False,  True,  True, False,  True, False,
#         True, False, False, False,  True, False, False, False, False,
#        False,  True, False,  True,  True, False, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False,  True, False,  True, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
(step_count > 5000) & (calories > 150)
# Out:
# array([ True,  True, False,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True,  True, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False,  True, False,  True,  True, False, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False, False, False,  True, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
print(sum((step_count > 5000) & (calories > 150)))
# Out:
# 17

# %%
#Another approac but it will use all data together not good for large set of data
len(data[(calories > 150) & (step_count>5000)])
# Out:
# 17

# %%
#What percentage of days had a "Sad" mood?

# %%
mood == 'Sad'
# Out:
# array([False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False,  True,  True, False, False, False, False, False,
#         True, False,  True, False, False,  True,  True,  True,  True,
#        False, False, False, False,  True,  True,  True, False, False,
#         True,  True, False, False, False, False])

# %%
#Approch1
len(mood[mood == 'Sad'])
# Out:
# 29

# %%
(len(mood[mood == 'Sad']) / len(mood))*100
# Out:
# 30.208333333333332

# %%
#Approach2 -it is going to count the true vaule only
np.sum(mood == 'Sad')
# Out:
# np.int64(29)

# %%
#Approach_3
x = len(data[mood =='Sad'])
y = len(data)
print(round(100*(x/y),2))
# Out:
# 30.21

# %%
# What is the maximum number of steps taken on days with less than 6 hours of sleep?

# %%
step_count
# Out:
# array([5464, 6041,   25, 5461, 6915, 4545, 4340, 1230,   61, 1258, 3148,
#        4687, 4732, 3519, 1580, 2822,  181, 3158, 4383, 3881, 4037,  202,
#         292,  330, 2209, 4550, 4435, 4779, 1831, 2255,  539, 5464, 6041,
#        4068, 4683, 4033, 6314,  614, 3149, 4005, 4880, 4136,  705,  570,
#         269, 4275, 5999, 4421, 6930, 5195,  546,  493,  995, 1163, 6676,
#        3608,  774, 1421, 4064, 2725, 5934, 1867, 3721, 2374, 2909, 1648,
#         799, 7102, 3941, 7422,  437, 1231, 1696, 4921,  221, 6500, 3575,
#        4061,  651,  753,  518, 5537, 4108, 5376, 3066,  177,   36,  299,
#        1447, 2599,  702,  133,  153,  500, 2127, 2203])

# %%
sleep < 6
# Out:
# array([ True, False,  True,  True,  True, False, False, False,  True,
#        False, False,  True, False, False,  True, False, False,  True,
#         True,  True, False, False,  True, False,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#        False,  True,  True, False,  True,  True, False,  True, False,
#         True, False,  True, False,  True, False, False, False, False,
#        False,  True, False, False, False, False, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True])

# %%
print(np.max(step_count[sleep < 6]))
# Out:
# 7422

# %%
#Approach_2---Using sort function
x = np.sort(step_count[sleep < 6])

# %%
print(x[-1])
# Out:
# 7422

# %%
# What are the average calories burned per hour of sleep on "Inactive" days?

# %%
activity == 'Inactive'
# Out:
# array([ True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False,  True, False, False, False, False, False,
#         True, False, False, False, False,  True,  True,  True,  True,
#        False, False, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True, False])

# %%
sleep[activity == 'Inactive']
# Out:
# array([5, 8, 5, 4, 6, 6, 7, 5, 6, 8, 5, 7, 5, 6, 8, 5, 4, 5, 6, 8, 5, 6,
#        5, 5, 4, 5, 4, 4, 3, 2, 9, 5, 5, 6, 5, 6, 5, 6, 4, 4, 4, 5, 5, 4,
#        3, 5, 3, 3, 3, 2, 3, 2, 8, 5])

# %%
calories[activity == 'Inactive']
# Out:
# array([181, 197,   0, 174, 149, 140,  38,   1,  40, 101, 152, 113,  49,
#         86,   6,  99, 143, 125, 129,   6,   9,  10,  72, 141, 156,  57,
#         72, 181, 197, 131, 154, 137, 145, 192, 146, 234, 167,  16,  76,
#         25,  55, 129,  21,  28,  16,   5,   1,  10,  47,  84,  23,   4,
#          0,   0])

# %%
print(np.mean(calories[activity == 'Inactive'] / sleep[activity == 'Inactive']))
# Out:
# 18.62282480893592

# %%
# Which mood had the highest average step count?

# %%
np.unique(mood)
# Out:
# array(['Happy', 'Neutral', 'Sad'], dtype='<U10')

# %%
x = np.mean(step_count[mood == 'Happy'])
y = np.mean(step_count[mood == 'Sad'])
z = np.mean(step_count[mood == 'Neutral'])

# %%
x
# Out:
# np.float64(3392.725)

# %%
y
# Out:
# np.float64(2103.0689655172414)

# %%
z
# Out:
# np.float64(3153.777777777778)

# %%
print(np.max([x,y,z]))
# Out:
# 3392.725

# %%
np.unique(mood)
# Out:
# array(['Happy', 'Neutral', 'Sad'], dtype='<U10')

# %%
#Approach2
[np.mean(step_count[mood==m]) for m in np.unique(mood)]
# Out:
# [np.float64(3392.725),
#  np.float64(3153.777777777778),
#  np.float64(2103.0689655172414)]

# %%
np.argmax([np.mean(step_count[mood==m]) for m in np.unique(mood)])
# Out:
# np.int64(0)

# %%
np.unique(mood)[0]
# Out:
# np.str_('Happy')

# %%
np.unique(mood)[np.argmax([np.mean(step_count[mood==m]) for m in np.unique(mood)])]
# Out:
# np.str_('Happy')

# %%
#QUESTION :- On how many days was the mood "Sad" and sleep less than the median sleep?

# %%
#Approach1
len(mood[ (mood == 'Sad') & (sleep < np.median(sleep)) ])
# Out:
# 10

# %%
#Approach2
x=np.median(sleep)
sum((mood=='Sad')&(sleep<x))
# Out:
# np.int64(10)
